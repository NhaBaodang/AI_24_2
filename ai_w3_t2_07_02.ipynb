# %% [markdown]
# <a href="https://colab.research.google.com/github/NhaBaodang/AI_24_2/blob/main/ai_w3_t2_07_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# create dataframe
dataframe = pd.DataFrame()
# add colums
dataframe["ten"]=['chanh','buoi','cam']
dataframe["price"]=[5,6,7]
dataframe["license"]=[True,False,True]
dataframe
# Out:
#      ten  price  license
# 0  chanh      5     True
# 1   buoi      6    False
# 2    cam      7     True

# %%
dataframe.shape
# Out:
# (3, 3)

# %%
df = dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ten      3 non-null      object
#  1   price    3 non-null      int64
#  2   license  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
list(df.columns)
# Out:
# ['ten', 'price', 'license']

# %%
df.describe()
# Out:
#        price
# count    3.0
# mean     6.0
# std      1.0
# min      5.0
# 25%      5.5
# 50%      6.0
# 75%      6.5
# max      7.0

# %%
df.loc[(df.price == 5)]
# Out:
#      ten  price  license
# 0  chanh      5     True

# %%
df.loc[(df.price == 5)| (df.ten == 'cam')]
# truy cap vao cac bien
# Out:
#      ten  price  license
# 0  chanh      5     True
# 2    cam      7     True

# %%
df.loc[(df.price == 5)| (df.ten == 'cam'),['ten','price']]
# chi truy cap vao ten va price
# Out:
#      ten  price
# 0  chanh      5
# 2    cam      7

# %%
df.iloc[2]
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
df.iloc[[2]]
# Out:
#    ten  price  license
# 2  cam      7     True

# %%
df.iloc[0:2,0:1]
# Out:
#      ten
# 0  chanh
# 1   buoi

# %%
df.iloc[0:2,-1]
# append a colunm in pandas
# Out:
# 0     True
# 1    False
# Name: license, dtype: bool

# %%
sum=df.price.sum()
print(sum)
# Out:
# 18

# %%
count = df['price'].count()
print(count)
# Out:
# 3

# %%
new = pd.Series(['xoai',10,True], index=['ten','price','license'])

dataframe.append(new,ignore_index=True)
# Out:
#      ten  price  license
# 0  chanh      5     True
# 1   buoi      6    False
# 2    cam      7     True
# 3   xoai     10     True

# %%
dataframe['vitri'] = ['my','anh','vietnam']
dataframe
# Out:
#      ten  price  license    vitri
# 0  chanh      5     True       my
# 1   buoi      6    False      anh
# 2    cam      7     True  vietnam

# %%
# xoa 1 hang
dataframe.drop(2,axis=0).head(10)
# xoa vij tris thu nhat
# Out:
#      ten  price  license vitri
# 0  chanh      5     True    my
# 1   buoi      6    False   anh

# %%
# xoa 1 cot
dataframe.drop('vitri',axis=1).head()
# Out:
#      ten  price  license
# 0  chanh      5     True
# 1   buoi      6    False
# 2    cam      7     True

# %%
# thay the gia tri
dataframe['price'].replace(5,7).head(5)
# Out:
# 0    7
# 1    6
# 2    7
# Name: price, dtype: int64

# %%
# doi ten 
dataframe.rename(columns={'price':'cost'}).head()
# Out:
#      ten  cost  license    vitri
# 0  chanh     5     True       my
# 1   buoi     6    False      anh
# 2    cam     7     True  vietnam

# %%
#2. knowing data

# %%
# load library
import pandas as pd
# create url
url = 'medals.csv'
# load data
dataframe = pd.read_csv(url)
# show data
dataframe.head(20)
# Out:
#     Year      City       Sport       Discipline  NOC                Event  \
# 0   1924  Chamonix     Skating   Figure skating  AUT           individual
# 1   1924  Chamonix     Skating   Figure skating  AUT           individual
# 2   1924  Chamonix     Skating   Figure skating  AUT                pairs
# 3   1924  Chamonix   Bobsleigh        Bobsleigh  BEL             four-man
# 4   1924  Chamonix  Ice Hockey       Ice Hockey  CAN           ice hockey
# 5   1924  Chamonix    Biathlon         Biathlon  FIN      military patrol
# 6   1924  Chamonix     Skating   Figure skating  FIN                pairs
# 7   1924  Chamonix     Skating    Speed skating  FIN               10000m
# 8   1924  Chamonix     Skating    Speed skating  FIN               10000m
# 9   1924  Chamonix     Skating    Speed skating  FIN                1500m
# 10  1924  Chamonix     Skating    Speed skating  FIN                5000m
# 11  1924  Chamonix     Skating    Speed skating  FIN                5000m
# ...

# %%
df=dataframe
count= df['Event gender'].count()
print(count)
# Out:
# 2311

# %%
df.loc[(df.Sport == 'Skating') & (df.Medal == 'Gold'),['Sport','Medal']]
# Out:
#         Sport Medal
# 1     Skating  Gold
# 2     Skating  Gold
# 7     Skating  Gold
# 9     Skating  Gold
# 10    Skating  Gold
# ...       ...   ...
# 2245  Skating  Gold
# 2293  Skating  Gold
# 2295  Skating  Gold
# 2299  Skating  Gold
# 2300  Skating  Gold
#
# [254 rows x 2 columns]

# %%
df.describe()
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
a=len(df)
print(a)
# Out:
# 2311

# %%
c = len(df.loc[(df.NOC == 'AUT') & (df.Medal == 'Gold')])
print(c)
# Out:
# 51

# %%
df['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
df['NOC'].unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'FIN', 'FRA', 'GBR', 'NOR', 'SUI', 'SWE',
#        'USA', 'GER', 'TCH', 'HUN', 'ITA', 'FRG', 'NED', 'EUA', 'JPN',
#        'POL', 'URS', 'PRK', 'GDR', 'ROU', 'ESP', 'LIE', 'BUL', 'YUG',
#        'CHN', 'EUN', 'KOR', 'LUX', 'NZL', 'AUS', 'BLR', 'KAZ', 'RUS',
#        'SLO', 'UKR', 'UZB', 'CZE', 'DEN', 'CRO', 'EST', 'LAT', 'SVK'],
#       dtype=object)

# %%
df = pd.read_csv(url)
df.groupby('NOC').head()
# Out:
#       Year      City       Sport       Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating   Figure skating  AUT       individual
# 1     1924  Chamonix     Skating   Figure skating  AUT       individual
# 2     1924  Chamonix     Skating   Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh        Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey       Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...              ...  ...              ...
# 2129  2006     Turin      Skiing  Cross Country S  EST             15km
# 2202  2006     Turin        Luge             Luge  LAT          singles
# 2269  2006     Turin      Skiing        Snowboard  SVK  Snowboard Cross
# 2284  2006     Turin    Biathlon         Biathlon  UKR            7.5km
# 2285  2006     Turin     Skating   Figure skating  UKR      ice dancing
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# ...

# %%
df.groupby('NOC').count()
# Out:
#      Year  City  Sport  Discipline  Event  Event gender  Medal
# NOC
# AUS     6     6      6           6      6             6      6
# AUT   185   185    185         185    185           185    185
# BEL     5     5      5           5      5             5      5
# BLR     6     6      6           6      6             6      6
# BUL     6     6      6           6      6             6      6
# CAN   119   119    119         119    119           119    119
# CHN    33    33     33          33     33            33     33
# CRO     7     7      7           7      7             7      7
# CZE    10    10     10          10     10            10     10
# DEN     1     1      1           1      1             1      1
# ESP     2     2      2           2      2             2      2
# EST     6     6      6           6      6             6      6
# EUA    19    19     19          19     19            19     19
# EUN    23    23     23          23     23            23     23
# ...

# %%
def uppercase(x):
  return x.upper()
df['Event'].apply(uppercase)[0:2011]
# Out:
# 0            INDIVIDUAL
# 1            INDIVIDUAL
# 2                 PAIRS
# 3              FOUR-MAN
# 4            ICE HOCKEY
#              ...
# 2006    K120 TEAM (90M)
# 2007            TWO-MAN
# 2008            TWO-MAN
# 2009         INDIVIDUAL
# 2010            CURLING
# Name: Event, Length: 2011, dtype: object

# %%
df.groupby(['Year','NOC']).count()
# Out:
#           City  Sport  Discipline  Event  Event gender  Medal
# Year NOC
# 1924 AUT     3      3           3      3             3      3
#      BEL     1      1           1      1             1      1
#      CAN     1      1           1      1             1      1
#      FIN    11     11          11     11            11     11
#      FRA     3      3           3      3             3      3
# ...        ...    ...         ...    ...           ...    ...
# 2006 SUI    14     14          14     14            14     14
#      SVK     1      1           1      1             1      1
#      SWE    14     14          14     14            14     14
#      UKR     2      2           2      2             2      2
#      USA    25     25          25     25            25     25
#
# [328 rows x 6 columns]

# %%
df[df['NOC']!='CAN'].head(10)
# Out:
#     Year      City      Sport      Discipline  NOC            Event  \
# 0   1924  Chamonix    Skating  Figure skating  AUT       individual
# 1   1924  Chamonix    Skating  Figure skating  AUT       individual
# 2   1924  Chamonix    Skating  Figure skating  AUT            pairs
# 3   1924  Chamonix  Bobsleigh       Bobsleigh  BEL         four-man
# 5   1924  Chamonix   Biathlon        Biathlon  FIN  military patrol
# 6   1924  Chamonix    Skating  Figure skating  FIN            pairs
# 7   1924  Chamonix    Skating   Speed skating  FIN           10000m
# 8   1924  Chamonix    Skating   Speed skating  FIN           10000m
# 9   1924  Chamonix    Skating   Speed skating  FIN            1500m
# 10  1924  Chamonix    Skating   Speed skating  FIN            5000m
#
#    Event gender   Medal
# 0             M  Silver
# 1             W    Gold
# 2             X    Gold
# 3             M  Bronze
# 5             M  Silver
# 6             X  Silver
# 7             M    Gold
# ...

# %%
df[(df['Year']>=1990)&(df['Year']<=2006) & (df['NOC']=='USA')&(df['Event gender']=='W')&(df['Medal']=='Gold')].head(10)
# Out:
#       Year         City       Sport      Discipline  NOC       Event  \
# 1428  1992  Albertville     Skating  Figure skating  USA  individual
# 1430  1992  Albertville     Skating  Short Track S.  USA        500m
# 1431  1992  Albertville     Skating   Speed skating  USA       1000m
# 1432  1992  Albertville     Skating   Speed skating  USA        500m
# 1436  1992  Albertville      Skiing  Freestyle Ski.  USA      moguls
# 1610  1994  Lillehammer     Skating  Short Track S.  USA        500m
# 1612  1994  Lillehammer     Skating   Speed skating  USA       1000m
# 1613  1994  Lillehammer     Skating   Speed skating  USA        500m
# 1617  1994  Lillehammer      Skiing   Alpine Skiing  USA     super-G
# 1812  1998       Nagano  Ice Hockey      Ice Hockey  USA  ice hockey
#
#      Event gender Medal
# 1428            W  Gold
# 1430            W  Gold
# 1431            W  Gold
# 1432            W  Gold
# 1436            W  Gold
# 1610            W  Gold
# 1612            W  Gold
# ...

# %%
df.drop('NOC', axis=1).head(10)
# Out:
#    Year      City       Sport      Discipline            Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating       individual            M
# 1  1924  Chamonix     Skating  Figure skating       individual            W
# 2  1924  Chamonix     Skating  Figure skating            pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh         four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey       ice hockey            M
# 5  1924  Chamonix    Biathlon        Biathlon  military patrol            M
# 6  1924  Chamonix     Skating  Figure skating            pairs            X
# 7  1924  Chamonix     Skating   Speed skating           10000m            M
# 8  1924  Chamonix     Skating   Speed skating           10000m            M
# 9  1924  Chamonix     Skating   Speed skating            1500m            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold
# 5  Silver
# 6  Silver
# 7    Gold
# 8  Silver
# 9    Gold

# %%
df
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...
